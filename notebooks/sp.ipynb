# %%
import sys
sys.path.insert(0, '/root/workspace/DEYO')

from ultralytics import RTDETR
model = RTDETR('/root/workspace/deyo_model/deyo-x.pt')

# %%
print("Class names:", model.names)

# %%
results = model.predict(
    source='/root/workspace/input_videos/protest.mp4',
    classes=[0],
    save=True,
    project='/root/workspace',
    name='protest_persons'
)

# %%
print("Video saved to: /root/workspace/protest_persons/protest.mp4")
